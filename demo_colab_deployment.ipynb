# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahilvohra58/ai-subtitle-video-editor/blob/main/demo_colab_deployment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Cloning the Github repo in the current directory

# %%
# !git init .
# !git remote add origin https://github.com/Sahilvohra58/ai-subtitle-video-editor.git
# !git pull origin main --allow-unrelated-histories
# Out:
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 52 (delta 21), reused 39 (delta 14), pack-reused 0
# Unpacking objects: 100% (52/52), done.
# From https://github.com/Sahilvohra58/ai-subtitle-video-editor
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %% [markdown]
# ## 2. Installing dependencies

# %%
# !bash apt_requirements.sh
# !bash pip install -r requirements.txt
# !sed -i '/<policy domain="path" rights="none" pattern="@\*"/d' /etc/ImageMagick-6/policy.xml
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.11-0ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gsfonts
#   imagemagick-6-common imagemagick-6.q16 libcupsfilters1 libcupsimage2
#   libdjvulibre-text libdjvulibre21 libgs9 libgs9-common libijs-0.35
#   libjbig2dec0 liblqr-1-0 libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra
#   libmagickwand-6.q16-3 libnetpbm10 libwmf0.2-7 netpbm poppler-data
# Suggested packages:
#   fonts-noto ghostscript-x imagemagick-doc autotrace cups-bsd | lpr | lprng
#   enscript gimp gnuplot grads hp2xx html2ps libwmf-bin mplayer povray radiance
#   sane-utils texlive-base-bin transfig ufraw-batch inkscape libjxr-tools
#   libwmf0.2-7-gtk poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gsfonts imagemagick
#   imagemagick-6-common imagemagick-6.q16 libcupsfilters1 libcupsimage2
#   libdjvulibre-text libdjvulibre21 libgs9 libgs9-common libijs-0.35
#   libjbig2dec0 liblqr-1-0 libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra
#   libmagickwand-6.q16-3 libnetpbm10 libwmf0.2-7 netpbm poppler-data
# 0 upgraded, 23 newly installed, 0 to remove and 20 not upgraded.
# Need to get 18.4 MB of archives.
# After this operation, 66.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblqr-1-0 amd64 0.4.2-2.1 [27.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 imagemagick-6-common all 8:6.9.7.4+dfsg-16ubuntu6.13 [60.3 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6.q16-3 amd64 8:6.9.7.4+dfsg-16ubuntu6.13 [1,620 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickwand-6.q16-3 amd64 8:6.9.7.4+dfsg-16ubuntu6.13 [292 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 poppler-data all 0.4.8-2 [1,479 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-noto-mono all 20171026-2 [75.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsimage2 amd64 2.2.7-1ubuntu2.9 [18.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libijs-0.35 amd64 0.35-13 [15.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjbig2dec0 amd64 0.13-6 [55.9 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9-common all 9.26~dfsg+0-0ubuntu0.18.04.16 [5,093 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9 amd64 9.26~dfsg+0-0ubuntu0.18.04.16 [2,265 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ghostscript amd64 9.26~dfsg+0-0ubuntu0.18.04.16 [51.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.4 [3,120 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 imagemagick-6.q16 amd64 8:6.9.7.4+dfsg-16ubuntu6.13 [423 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 imagemagick amd64 8:6.9.7.4+dfsg-16ubuntu6.13 [14.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsfilters1 amd64 1.20.2-0ubuntu3.1 [108 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdjvulibre-text all 3.5.27.1-8ubuntu0.4 [49.4 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdjvulibre21 amd64 3.5.27.1-8ubuntu0.4 [561 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libwmf0.2-7 amd64 0.2.8.4-12 [150 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagickcore-6.q16-3-extra amd64 8:6.9.7.4+dfsg-16ubuntu6.13 [62.3 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnetpbm10 amd64 2:10.0-15.3build1 [58.0 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 netpbm amd64 2:10.0-15.3build1 [1,017 kB]
# Fetched 18.4 MB in 1s (15.5 MB/s)
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 155676 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Selecting previously unselected package liblqr-1-0:amd64.
# Preparing to unpack .../01-liblqr-1-0_0.4.2-2.1_amd64.deb ...
# Unpacking liblqr-1-0:amd64 (0.4.2-2.1) ...
# Selecting previously unselected package imagemagick-6-common.
# Preparing to unpack .../02-imagemagick-6-common_8%3a6.9.7.4+dfsg-16ubuntu6.13_all.deb ...
# Unpacking imagemagick-6-common (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Selecting previously unselected package libmagickcore-6.q16-3:amd64.
# Preparing to unpack .../03-libmagickcore-6.q16-3_8%3a6.9.7.4+dfsg-16ubuntu6.13_amd64.deb ...
# Unpacking libmagickcore-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Selecting previously unselected package libmagickwand-6.q16-3:amd64.
# Preparing to unpack .../04-libmagickwand-6.q16-3_8%3a6.9.7.4+dfsg-16ubuntu6.13_amd64.deb ...
# Unpacking libmagickwand-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../05-poppler-data_0.4.8-2_all.deb ...
# Unpacking poppler-data (0.4.8-2) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../06-fonts-noto-mono_20171026-2_all.deb ...
# Unpacking fonts-noto-mono (20171026-2) ...
# Selecting previously unselected package libcupsimage2:amd64.
# Preparing to unpack .../07-libcupsimage2_2.2.7-1ubuntu2.9_amd64.deb ...
# Unpacking libcupsimage2:amd64 (2.2.7-1ubuntu2.9) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../08-libijs-0.35_0.35-13_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-13) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../09-libjbig2dec0_0.13-6_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.13-6) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../10-libgs9-common_9.26~dfsg+0-0ubuntu0.18.04.16_all.deb ...
# Unpacking libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.16) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../11-libgs9_9.26~dfsg+0-0ubuntu0.18.04.16_amd64.deb ...
# Unpacking libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.16) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../12-ghostscript_9.26~dfsg+0-0ubuntu0.18.04.16_amd64.deb ...
# Unpacking ghostscript (9.26~dfsg+0-0ubuntu0.18.04.16) ...
# Selecting previously unselected package gsfonts.
# Preparing to unpack .../13-gsfonts_1%3a8.11+urwcyr1.0.7~pre44-4.4_all.deb ...
# Unpacking gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Selecting previously unselected package imagemagick-6.q16.
# Preparing to unpack .../14-imagemagick-6.q16_8%3a6.9.7.4+dfsg-16ubuntu6.13_amd64.deb ...
# Unpacking imagemagick-6.q16 (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Selecting previously unselected package imagemagick.
# Preparing to unpack .../15-imagemagick_8%3a6.9.7.4+dfsg-16ubuntu6.13_amd64.deb ...
# Unpacking imagemagick (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Selecting previously unselected package libcupsfilters1:amd64.
# Preparing to unpack .../16-libcupsfilters1_1.20.2-0ubuntu3.1_amd64.deb ...
# Unpacking libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Selecting previously unselected package libdjvulibre-text.
# Preparing to unpack .../17-libdjvulibre-text_3.5.27.1-8ubuntu0.4_all.deb ...
# Unpacking libdjvulibre-text (3.5.27.1-8ubuntu0.4) ...
# Selecting previously unselected package libdjvulibre21:amd64.
# Preparing to unpack .../18-libdjvulibre21_3.5.27.1-8ubuntu0.4_amd64.deb ...
# Unpacking libdjvulibre21:amd64 (3.5.27.1-8ubuntu0.4) ...
# Selecting previously unselected package libwmf0.2-7:amd64.
# Preparing to unpack .../19-libwmf0.2-7_0.2.8.4-12_amd64.deb ...
# Unpacking libwmf0.2-7:amd64 (0.2.8.4-12) ...
# Selecting previously unselected package libmagickcore-6.q16-3-extra:amd64.
# Preparing to unpack .../20-libmagickcore-6.q16-3-extra_8%3a6.9.7.4+dfsg-16ubuntu6.13_amd64.deb ...
# Unpacking libmagickcore-6.q16-3-extra:amd64 (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Selecting previously unselected package libnetpbm10.
# Preparing to unpack .../21-libnetpbm10_2%3a10.0-15.3build1_amd64.deb ...
# Unpacking libnetpbm10 (2:10.0-15.3build1) ...
# Selecting previously unselected package netpbm.
# Preparing to unpack .../22-netpbm_2%3a10.0-15.3build1_amd64.deb ...
# Unpacking netpbm (2:10.0-15.3build1) ...
# Setting up libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.16) ...
# Setting up imagemagick-6-common (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Setting up gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Setting up poppler-data (0.4.8-2) ...
# Setting up libdjvulibre-text (3.5.27.1-8ubuntu0.4) ...
# Setting up libnetpbm10 (2:10.0-15.3build1) ...
# Setting up fonts-noto-mono (20171026-2) ...
# Setting up libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Setting up libcupsimage2:amd64 (2.2.7-1ubuntu2.9) ...
# Setting up liblqr-1-0:amd64 (0.4.2-2.1) ...
# Setting up libjbig2dec0:amd64 (0.13-6) ...
# Setting up libijs-0.35:amd64 (0.35-13) ...
# Setting up netpbm (2:10.0-15.3build1) ...
# Setting up libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.16) ...
# Setting up libwmf0.2-7:amd64 (0.2.8.4-12) ...
# Setting up libmagickcore-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Setting up libdjvulibre21:amd64 (3.5.27.1-8ubuntu0.4) ...
# Setting up ghostscript (9.26~dfsg+0-0ubuntu0.18.04.16) ...
# Setting up libmagickwand-6.q16-3:amd64 (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Setting up imagemagick-6.q16 (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# update-alternatives: using /usr/bin/compare-im6.q16 to provide /usr/bin/compare (compare) in auto mode
# update-alternatives: using /usr/bin/compare-im6.q16 to provide /usr/bin/compare-im6 (compare-im6) in auto mode
# update-alternatives: using /usr/bin/animate-im6.q16 to provide /usr/bin/animate (animate) in auto mode
# update-alternatives: using /usr/bin/animate-im6.q16 to provide /usr/bin/animate-im6 (animate-im6) in auto mode
# update-alternatives: using /usr/bin/convert-im6.q16 to provide /usr/bin/convert (convert) in auto mode
# update-alternatives: using /usr/bin/convert-im6.q16 to provide /usr/bin/convert-im6 (convert-im6) in auto mode
# update-alternatives: using /usr/bin/composite-im6.q16 to provide /usr/bin/composite (composite) in auto mode
# update-alternatives: using /usr/bin/composite-im6.q16 to provide /usr/bin/composite-im6 (composite-im6) in auto mode
# update-alternatives: using /usr/bin/conjure-im6.q16 to provide /usr/bin/conjure (conjure) in auto mode
# update-alternatives: using /usr/bin/conjure-im6.q16 to provide /usr/bin/conjure-im6 (conjure-im6) in auto mode
# update-alternatives: using /usr/bin/import-im6.q16 to provide /usr/bin/import (import) in auto mode
# update-alternatives: using /usr/bin/import-im6.q16 to provide /usr/bin/import-im6 (import-im6) in auto mode
# update-alternatives: using /usr/bin/identify-im6.q16 to provide /usr/bin/identify (identify) in auto mode
# update-alternatives: using /usr/bin/identify-im6.q16 to provide /usr/bin/identify-im6 (identify-im6) in auto mode
# update-alternatives: using /usr/bin/stream-im6.q16 to provide /usr/bin/stream (stream) in auto mode
# update-alternatives: using /usr/bin/stream-im6.q16 to provide /usr/bin/stream-im6 (stream-im6) in auto mode
# update-alternatives: using /usr/bin/display-im6.q16 to provide /usr/bin/display (display) in auto mode
# update-alternatives: using /usr/bin/display-im6.q16 to provide /usr/bin/display-im6 (display-im6) in auto mode
# update-alternatives: using /usr/bin/montage-im6.q16 to provide /usr/bin/montage (montage) in auto mode
# update-alternatives: using /usr/bin/montage-im6.q16 to provide /usr/bin/montage-im6 (montage-im6) in auto mode
# update-alternatives: using /usr/bin/mogrify-im6.q16 to provide /usr/bin/mogrify (mogrify) in auto mode
# update-alternatives: using /usr/bin/mogrify-im6.q16 to provide /usr/bin/mogrify-im6 (mogrify-im6) in auto mode
# Setting up libmagickcore-6.q16-3-extra:amd64 (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Setting up imagemagick (8:6.9.7.4+dfsg-16ubuntu6.13) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: PyYAML==6.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (6.0)
# Requirement already satisfied: Pandas==1.3.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (1.3.5)
# Collecting Moviepy==1.0.3
#   Downloading moviepy-1.0.3.tar.gz (388 kB)
#      |████████████████████████████████| 388 kB 7.9 MB/s
# Collecting flask==2.2.2
#   Downloading Flask-2.2.2-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 13.2 MB/s
# Collecting flask_sqlalchemy==2.5.1
#   Downloading Flask_SQLAlchemy-2.5.1-py2.py3-none-any.whl (17 kB)
# Collecting argparse==1.1
#   Downloading argparse-1.1.zip (151 kB)
#      |████████████████████████████████| 151 kB 54.1 MB/s
# Collecting google-cloud-speech
#   Downloading google_cloud_speech-2.15.1-py2.py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 55.2 MB/s
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from Pandas==1.3.5->-r requirements.txt (line 2)) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from Pandas==1.3.5->-r requirements.txt (line 2)) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from Pandas==1.3.5->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from Moviepy==1.0.3->-r requirements.txt (line 3)) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from Moviepy==1.0.3->-r requirements.txt (line 3)) (4.64.0)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.7/dist-packages (from Moviepy==1.0.3->-r requirements.txt (line 3)) (2.23.0)
# Collecting proglog<=1.0.0
#   Downloading proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.7/dist-packages (from Moviepy==1.0.3->-r requirements.txt (line 3)) (2.9.0)
# Collecting imageio_ffmpeg>=0.2.0
#   Downloading imageio_ffmpeg-0.4.7-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#      |████████████████████████████████| 26.9 MB 1.5 MB/s
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting Jinja2>=3.0
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 64.9 MB/s
# Collecting Werkzeug>=2.2.2
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      |████████████████████████████████| 232 kB 58.7 MB/s
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from flask==2.2.2->-r requirements.txt (line 4)) (4.12.0)
# Collecting click>=8.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 8.2 MB/s
# Requirement already satisfied: SQLAlchemy>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from flask_sqlalchemy==2.5.1->-r requirements.txt (line 5)) (1.4.40)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.5->Moviepy==1.0.3->-r requirements.txt (line 3)) (7.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6.0->flask==2.2.2->-r requirements.txt (line 4)) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6.0->flask==2.2.2->-r requirements.txt (line 4)) (4.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=3.0->flask==2.2.2->-r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->Pandas==1.3.5->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->Moviepy==1.0.3->-r requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->Moviepy==1.0.3->-r requirements.txt (line 3)) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->Moviepy==1.0.3->-r requirements.txt (line 3)) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->Moviepy==1.0.3->-r requirements.txt (line 3)) (2.10)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy>=0.8.0->flask_sqlalchemy==2.5.1->-r requirements.txt (line 5)) (1.1.2)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0
#   Downloading google_api_core-2.8.2-py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 56.7 MB/s
# Collecting proto-plus<2.0.0dev,>=1.22.0
#   Downloading proto_plus-1.22.0-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 5.9 MB/s
# Collecting protobuf<5.0.0dev,>=3.19.0
#   Downloading protobuf-4.21.5-cp37-abi3-manylinux2014_x86_64.whl (408 kB)
#      |████████████████████████████████| 408 kB 60.2 MB/s
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (1.35.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (1.56.4)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (1.47.0)
# Collecting grpcio-status<2.0dev,>=1.33.2
#   Downloading grpcio_status-1.47.0-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (4.2.4)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (57.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (0.4.8)
# Building wheels for collected packages: Moviepy, argparse
#   Building wheel for Moviepy (setup.py) ... done
#   Created wheel for Moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110743 sha256=b1fac0068c68f9bf0673cc24ac4670564add13e841b89d2b64df3a0a437f8cb9
#   Stored in directory: /root/.cache/pip/wheels/56/dc/2b/9cd600d483c04af3353d66623056fc03faed76b7518faae4df
#   Building wheel for argparse (setup.py) ... done
#   Created wheel for argparse: filename=argparse-1.1-py3-none-any.whl size=20735 sha256=e8d5ad8f153fd2b2139d1b93044e815ebe96276da5abac343f312945b3ffc7e9
#   Stored in directory: /root/.cache/pip/wheels/59/e1/77/ca719b6be5cfdef5d09090cb37f86df1d9bbdd0749a0e48860
# Successfully built Moviepy argparse
# Installing collected packages: protobuf, MarkupSafe, Werkzeug, Jinja2, itsdangerous, grpcio-status, google-api-core, click, proto-plus, proglog, imageio-ffmpeg, flask, Moviepy, google-cloud-speech, flask-sqlalchemy, argparse
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 1.31.6
#     Uninstalling google-api-core-1.31.6:
#       Successfully uninstalled google-api-core-1.31.6
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
#   Attempting uninstall: flask
#     Found existing installation: Flask 1.1.4
#     Uninstalling Flask-1.1.4:
#       Successfully uninstalled Flask-1.1.4
#   Attempting uninstall: Moviepy
#     Found existing installation: moviepy 0.2.3.5
#     Uninstalling moviepy-0.2.3.5:
#       Successfully uninstalled moviepy-0.2.3.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.2+zzzcolab20220719082949 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.21.5 which is incompatible.
# tensorflow-metadata 1.9.0 requires protobuf<4,>=3.13, but you have protobuf 4.21.5 which is incompatible.
# google-cloud-translate 1.5.0 requires google-api-core[grpc]<2.0.0dev,>=1.6.0, but you have google-api-core 2.8.2 which is incompatible.
# google-cloud-language 1.2.0 requires google-api-core[grpc]<2.0.0dev,>=1.6.0, but you have google-api-core 2.8.2 which is incompatible.
# google-cloud-firestore 1.7.0 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.8.2 which is incompatible.
# google-cloud-datastore 1.8.0 requires google-api-core[grpc]<2.0.0dev,>=1.6.0, but you have google-api-core 2.8.2 which is incompatible.
# google-cloud-core 1.0.3 requires google-api-core<2.0.0dev,>=1.14.0, but you have google-api-core 2.8.2 which is incompatible.
# google-cloud-bigquery-storage 1.1.2 requires protobuf<4.0.0dev, but you have protobuf 4.21.5 which is incompatible.
# firebase-admin 4.4.0 requires google-api-core[grpc]<2.0.0dev,>=1.14.0; platform_python_implementation != "PyPy", but you have google-api-core 2.8.2 which is incompatible.
# Successfully installed Jinja2-3.1.2 MarkupSafe-2.1.1 Moviepy-1.0.3 Werkzeug-2.2.2 argparse-1.1 click-8.1.3 flask-2.2.2 flask-sqlalchemy-2.5.1 google-api-core-2.8.2 google-cloud-speech-2.15.1 grpcio-status-1.47.0 imageio-ffmpeg-0.4.7 itsdangerous-2.1.2 proglog-0.1.10 proto-plus-1.22.0 protobuf-4.21.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: PyYAML==6.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (6.0)
# Requirement already satisfied: Pandas==1.3.5 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (1.3.5)
# Requirement already satisfied: Moviepy==1.0.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (1.0.3)
# Requirement already satisfied: flask==2.2.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (2.2.2)
# Requirement already satisfied: flask_sqlalchemy==2.5.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (2.5.1)
# Collecting argparse==1.1
#   Using cached argparse-1.1-py3-none-any.whl
# Requirement already satisfied: google-cloud-speech in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 7)) (2.15.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from Pandas==1.3.5->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from Pandas==1.3.5->-r requirements.txt (line 2)) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from Pandas==1.3.5->-r requirements.txt (line 2)) (2022.2.1)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from Moviepy==1.0.3->-r requirements.txt (line 3)) (4.64.0)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.7/dist-packages (from Moviepy==1.0.3->-r requirements.txt (line 3)) (2.9.0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from Moviepy==1.0.3->-r requirements.txt (line 3)) (4.4.2)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.7/dist-packages (from Moviepy==1.0.3->-r requirements.txt (line 3)) (2.23.0)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.7/dist-packages (from Moviepy==1.0.3->-r requirements.txt (line 3)) (0.1.10)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from Moviepy==1.0.3->-r requirements.txt (line 3)) (0.4.7)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.7/dist-packages (from flask==2.2.2->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from flask==2.2.2->-r requirements.txt (line 4)) (4.12.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from flask==2.2.2->-r requirements.txt (line 4)) (2.2.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.7/dist-packages (from flask==2.2.2->-r requirements.txt (line 4)) (8.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.7/dist-packages (from flask==2.2.2->-r requirements.txt (line 4)) (2.1.2)
# Requirement already satisfied: SQLAlchemy>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from flask_sqlalchemy==2.5.1->-r requirements.txt (line 5)) (1.4.40)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.5->Moviepy==1.0.3->-r requirements.txt (line 3)) (7.1.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6.0->flask==2.2.2->-r requirements.txt (line 4)) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6.0->flask==2.2.2->-r requirements.txt (line 4)) (3.8.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=3.0->flask==2.2.2->-r requirements.txt (line 4)) (2.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->Pandas==1.3.5->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->Moviepy==1.0.3->-r requirements.txt (line 3)) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->Moviepy==1.0.3->-r requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->Moviepy==1.0.3->-r requirements.txt (line 3)) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.8.1->Moviepy==1.0.3->-r requirements.txt (line 3)) (2.10)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy>=0.8.0->flask_sqlalchemy==2.5.1->-r requirements.txt (line 5)) (1.1.2)
# Requirement already satisfied: protobuf<5.0.0dev,>=3.19.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-speech->-r requirements.txt (line 7)) (4.21.5)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-speech->-r requirements.txt (line 7)) (1.22.0)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-speech->-r requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (1.35.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (1.56.4)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (1.47.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.7/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (1.47.0)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (57.4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (0.2.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-speech->-r requirements.txt (line 7)) (0.4.8)
# Installing collected packages: argparse
# Successfully installed argparse-1.1

# %%
# Set video and service account credentials files manually if already uploaded. In that case dont run the next two cells.
# video_file_name = "Sahil.mp4"
# service_account = "service-account.json"

# %%
from google.colab import files
print("Upload video file")
uploaded = files.upload()
video_file_name = list(uploaded.keys())[0]
video_file_name
# Out:
# Upload video file
#      <input type="file" id="files-ae85f2f9-d42b-4e96-873b-967783ab6682" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae85f2f9-d42b-4e96-873b-967783ab6682">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Sahil.mp4 to Sahil.mp4
# 'Sahil.mp4'

# %%
#https://roytuts.com/upload-and-play-video-using-flask/

# %%
print('Upload service account credentials')
uploaded = files.upload()
service_account = list(uploaded.keys())[0]
service_account
# Out:
# Upload service account credentials
#      <input type="file" id="files-b0d5eedb-3b8b-4301-924c-e10296d0790e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0d5eedb-3b8b-4301-924c-e10296d0790e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving service-account.json to service-account.json
# 'service-account.json'

# %% [markdown]
# ## 3. Starting the app.
#
# ### Open the app URL to interact the app

# %%
# !pip install pyngrok
from pyngrok import ngrok
ngrok.set_auth_token("2DxG4u8dRkUJi7cHHHbBlpu2RQN_2Avsvy7HKsDA8KE4wzqgs")
ngrok_port = 5000

# %%
try:
  public_url = ngrok.connect(ngrok_port).public_url
except:
  print("public url already created: ", public_url)
  
print("app URL: ", public_url)
cmd = f"""python main.py --video_file_name {video_file_name} --service_account_json {service_account} --app_port {ngrok_port}"""
with open('run.sh', 'w') as file:
  file.write(cmd)
# !bash run.sh
# Out:
# app URL:  http://99c8-34-125-68-91.ngrok.io
# MoviePy - Writing audio in temp_files/Sahil_audio.mp3
# MoviePy - Done.
# Requesting API
# DEBUG:google.auth._default:Checking service-account.json for explicit credentials as part of auth process...
# Received response. Processing response
# Data processed
# populating db
#  * Serving Flask app 'app'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:3000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with stat
# populating db
# WARNING:werkzeug: * Debugger is active!
# INFO:werkzeug: * Debugger PIN: 322-892-207
# INFO:werkzeug:127.0.0.1 - - [28/Aug/2022 15:29:14] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [28/Aug/2022 15:29:14] "GET /static/css/main.css HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [28/Aug/2022 15:29:14] "GET /favicon.ico HTTP/1.1" 404 -
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5210
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5341 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5390 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5439 39
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5025
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5156 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5205 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5254 35
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5756
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5887 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5936 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5985 39
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5372
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5503 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5552 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5601 43
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 4226
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4357 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4406 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4455 34
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5629
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5760 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5809 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5858 47
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 4098
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4229 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4278 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4327 39
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 4898
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5029 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5078 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5127 38
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5201
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5332 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5381 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5430 37
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 3972
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4103 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4152 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4201 30
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5952
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 6083 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 6132 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 6181 54
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 4669
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4800 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4849 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4898 37
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 3487
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 3618 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 3667 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 3716 33
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 4494
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4625 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4674 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4723 32
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 4941
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5072 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5121 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5170 33
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5528
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5659 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5708 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5757 35
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 3752
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 3883 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 3932 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 3981 32
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 3908
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4039 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4088 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4137 32
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 4039
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4170 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4219 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4268 31
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 7010
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 7141 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 7190 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 7239 41
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5512
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5643 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5692 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5741 35
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 4764
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4895 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4944 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4993 42
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 4489
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4620 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4669 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4718 38
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5398
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5529 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5578 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5627 45
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5139
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5270 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5319 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5368 40
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5018
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5149 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5198 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5247 33
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 4705
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4836 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4885 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4934 39
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5052
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5183 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5232 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5281 34
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 4466
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4597 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4646 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 4695 37
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5644
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5775 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5824 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5873 39
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 5302
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5433 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5482 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 5531 38
# <class 'float'> <class 'float'> <class 'str'>
# black
# DEBUG:PIL.PngImagePlugin:STREAM b'IHDR' 16 13
# DEBUG:PIL.PngImagePlugin:STREAM b'gAMA' 41 4
# DEBUG:PIL.PngImagePlugin:STREAM b'cHRM' 57 32
# DEBUG:PIL.PngImagePlugin:STREAM b'bKGD' 101 6
# DEBUG:PIL.PngImagePlugin:b'bKGD' 101 6 (unknown)
# DEBUG:PIL.PngImagePlugin:STREAM b'IDAT' 119 6016
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 6147 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 6196 37
# DEBUG:PIL.PngImagePlugin:STREAM b'tEXt' 6245 37
# Moviepy - Building video Sahil_edited.mp4.
# MoviePy - Writing audio in temp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video Sahil_edited.mp4
#
# t: 100% 2062/2063 [02:21<00:00, 12.68it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.7/dist-packages/moviepy/video/io/ffmpeg_reader.py:130: UserWarning: Warning: in file Sahil.mp4, 2764800 bytes wanted but 0 bytes read,at frame 2062/2063, at time 68.73/68.76 sec. Using the last valid frame instead.
#   UserWarning)
#
# Moviepy - Done !
# Moviepy - video ready Sahil_edited.mp4
# INFO:werkzeug:127.0.0.1 - - [28/Aug/2022 15:31:56] "POST /produce HTTP/1.1" 302 -
# INFO:werkzeug:127.0.0.1 - - [28/Aug/2022 15:31:57] "GET /download HTTP/1.1" 200 -
